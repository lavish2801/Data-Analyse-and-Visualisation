# %% [markdown]
# Q. 1)  Find all the unique 'Wind Speed' values in the data.
# Q. 2) Find the number of times when the 'Weather is exactly Clear'.
# Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.
# Q. 4) Find out all the Null Values in the data.
# Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.
# Q. 6) What is the mean 'Visibility' ?
# Q. 7) What is the Standard Deviation of 'Pressure'  in this data?
# Q. 8) What is the Variance of 'Relative Humidity' in this data ?
# Q. 9) Find all instances when 'Snow' was recorded.
# Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.
# Q. 11) What is the Mean value of each column against each 'Weather Condition ?
# Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?
# Q. 13) Show all the Records where Weather Condition is Fog.
# Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.
# Q. 15) Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# or
# B. 'Visibility is above 40'

# %% [markdown]
# ## Weather Dataset

# %%
# import libraries
import pandas as pd

# %%
df=pd.read_csv("Weather Data.csv")

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
len(df)
# Out:
# 8784

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time           8784 non-null object
# Temp_C              8784 non-null float64
# Dew Point Temp_C    8784 non-null float64
# Rel Hum_%           8784 non-null int64
# Wind Speed_km/h     8784 non-null int64
# Visibility_km       8784 non-null float64
# Press_kPa           8784 non-null float64
# Weather             8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ##  1. Find all the unique 'Wind Speed' values in the data.

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df["Wind Speed_km/h"].nunique() # print total unique value
# Out:
# 34

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# ## 2. Find the number of times when the 'Weather is exactly Clear'.

# %%
df["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
# .count === show total number of non -null in each column

df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# .value_count() == show count in single column

# Lets check For weather

df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df["Weather"]=="Clear"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df.groupby("Weather").get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# ## 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
df["Wind Speed_km/h"].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 63      1
# 54      1
# 70      1
# 83      1
# Name: Wind Speed_km/h, dtype: int64

# %%
df[df["Wind Speed_km/h"]==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # 4) Find out all the Null Values in the data.

# %%
data=df.dropna() # Droped all null values
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# check using isnull()

df.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
df.isnull().sum()  #Check total Sum of null values
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()   # Checkk total not null values
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# ##  5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
df_copy=df.copy()

# %%
df_copy
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.rename(columns={"Weather": "Weather Condition"}) # this prints data temporary , for permanent use inplace
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.rename(columns={"Weather": "Weather Condition"}, inplace= True) # this prints data temporary , for permanent use inplace
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 6) What is the mean 'Visibility'

# %%
df.describe() # complete data
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df["Visibility_km"].mean()
# Out:
# 27.66444672131151

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
# Date/Time            8784 non-null object
# Temp_C               8784 non-null float64
# Dew Point Temp_C     8784 non-null float64
# Rel Hum_%            8784 non-null int64
# Wind Speed_km/h      8784 non-null int64
# Visibility_km        8784 non-null float64
# Press_kPa            8784 non-null float64
# Weather Condition    8784 non-null object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# ## 7) What is the Standard Deviation of 'Pressure' in this data?

# %%
df.describe( include=object)
# Out:
#                Date/Time Weather Condition
# count               8784              8784
# unique              8784                50
# top     12/10/2012 20:00      Mainly Clear
# freq                   1              2106

# %%
import numpy as np

pd.set_option("display.precision",2)
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df["Press_kPa"].std()
# Out:
# 0.8440047459486474

# %%
#rounding off to 2 decimal

round(df["Press_kPa"].std(),2)
# Out:
# 0.84

# %% [markdown]
# ##  8) What is the Variance of 'Relative Humidity' in this data ?

# %%
df["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# ## 9) Find all instances when 'Snow' was recorded.

# %%
df[df["Weather Condition"]=="Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df["Weather Condition"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# now want each type of snow use string contributes

df[df["Weather Condition"].str.contains("Snow")]  # you can use .head() and .tail() according to covinence
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)].loc[:,("Wind Speed_km/h","Visibility_km")]
# Out:
#       Wind Speed_km/h  Visibility_km
# 23                 30           25.0
# 24                 35           25.0
# 25                 39           25.0
# 26                 32           25.0
# 27                 33           25.0
# ...               ...            ...
# 8705               26           25.0
# 8753               28           25.0
# 8755               26           25.0
# 8759               28           25.0
# 8760               26           25.0
#
# [308 rows x 2 columns]

# %% [markdown]
# ## 11) What is the Mean value of each column against each 'Weather Condition ?

# %%
df.groupby("Weather Condition").mean()
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather Condition
# Clear                                      6.83              0.09      64.50
# Cloudy                                     7.97              2.38      69.59
# Drizzle                                    7.35              5.50      88.24
# Drizzle,Fog                                8.07              7.03      93.28
# Drizzle,Ice Pellets,Fog                    0.40             -0.70      92.00
# Drizzle,Snow                               1.05              0.15      93.50
# Drizzle,Snow,Fog                           0.69              0.12      95.87
# Fog                                        4.30              3.16      92.29
# Freezing Drizzle                          -5.66             -8.00      83.57
# Freezing Drizzle,Fog                      -2.53             -4.18      88.50
# Freezing Drizzle,Haze                     -5.43             -8.00      82.00
# ...

# %%
# Complete data with respect to Weather Condition

df.groupby("Weather Condition").describe()
# Out:
#                                          Temp_C                             \
#                                           count   mean    std   min    25%
# Weather Condition
# Clear                                    1326.0   6.83  12.13 -23.3  -3.10
# Cloudy                                   1728.0   7.97  11.00 -21.4   0.40
# Drizzle                                    41.0   7.35   5.30   1.1   2.30
# Drizzle,Fog                                80.0   8.07   4.97   0.0   3.65
# Drizzle,Ice Pellets,Fog                     1.0   0.40    NaN   0.4   0.40
# Drizzle,Snow                                2.0   1.05   0.21   0.9   0.98
# Drizzle,Snow,Fog                           15.0   0.69   0.32   0.3   0.40
# Fog                                       150.0   4.30   8.04 -16.0  -0.65
# Freezing Drizzle                            7.0  -5.66   2.02  -9.0  -6.30
# Freezing Drizzle,Fog                        6.0  -2.53   2.12  -6.4  -2.95
# ...

# %% [markdown]
# ## 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
# maximum against weather conditon

df.groupby("Weather Condition").max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
# min of each column against Weather condition

df.groupby("Weather Condition").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %% [markdown]
#  ## 13) Show all the Records where Weather Condition is Fog.

# %%
df[df["Weather Condition"]=="Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# 5        1/1/2012 5:00    -1.4              -3.3         87                9
# 6        1/1/2012 6:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
# IF use string constraints

df[df["Weather Condition"].str.contains("Fog")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8739   12/30/2012 3:00    -9.1             -10.4         90               11
# 8740   12/30/2012 4:00    -9.3             -10.6         90               13
# 8741   12/30/2012 5:00    -9.1             -10.4         90               11
# 8742   12/30/2012 6:00    -9.3             -10.8         89               17
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
#
# ...

# %% [markdown]
# ## 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
df[(df["Weather Condition"].str.contains("Clear")) | (df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 36      1/2/2012 12:00     1.7              -6.2         56               48
# 60      1/3/2012 12:00   -14.9             -22.6         52               20
# 61      1/3/2012 13:00   -15.1             -22.4         54               22
# 62      1/3/2012 14:00   -14.9             -22.9         50               22
# 63      1/3/2012 15:00   -14.8             -22.2         53               19
# ...                ...     ...               ...        ...              ...
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8757  12/30/2012 21:00   -13.8             -16.5         80               20
# 8758  12/30/2012 22:00   -13.7             -16.3         81               19
#
# ...

# %%
df["Visibility_km"].value_counts()
# Out:
# 25.0    3324
# 48.3    2014
# 24.1    1921
# 19.3     281
# 16.1     224
# 9.7      181
# 12.9     174
# 6.4      129
# 8.0      122
# 4.8       79
# 4.0       55
# 2.4       50
# 3.2       42
# 11.3      36
# 2.0       28
# 1.2       28
# 1.6       25
# 0.6       16
# 2.8       15
# 1.0       11
# 3.6       11
# 0.2        8
# 0.8        7
# 0.4        3
# Name: Visibility_km, dtype: int64

# %% [markdown]
# ## 15) Find all instances when : A. 'Weather is Clear' and 'Relative Humidity is greater than 50' or B. 'Visibility is above 40'

# %%
df[(df["Weather Condition"].str.contains("Clear")) & (df["Rel Hum_%"]>50) | (df["Visibility_km"]>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 36      1/2/2012 12:00     1.7              -6.2         56               48
# 60      1/3/2012 12:00   -14.9             -22.6         52               20
# 61      1/3/2012 13:00   -15.1             -22.4         54               22
# 63      1/3/2012 15:00   -14.8             -22.2         53               19
# 64      1/3/2012 16:00   -15.3             -22.9         52               22
# ...                ...     ...               ...        ...              ...
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
# 8757  12/30/2012 21:00   -13.8             -16.5         80               20
# 8758  12/30/2012 22:00   -13.7             -16.3         81               19
#
# ...

# %% [markdown]
# # DATA VISUALISATION Using Pandas Library

# %%
# Line Plot using pandas library between Weather condition and (temp , humidity) relation

dfa=df[df["Weather Condition"]=="Clear"]
dfa.plot(x="Weather Condition" ,y=["Temp_C","Rel Hum_%"])

# %%
# Bar Graph

dfa.plot.bar(x="Weather Condition" ,y=["Temp_C"], figsize=(20,10)).set(ylabel="Temperature",title="Bar Graph")
#dfa.plot(figsize=(20, 10))
# Out:
# [Text(0, 0.5, 'Temperature'), Text(0.5, 1.0, 'Bar Graph')]

# %%
# Scatter Graph 
dfa=df.head(50)
dfa.plot.scatter(x="Temp_C" ,y="Visibility_km")

# %%
# Copy table in different dataframe variable 

t=df.copy()
t
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
#  # Data Visualisation Using MatplotLib

# %%
#import library

import matplotlib.pyplot as plt
import numpy as np

# %%
# Line Plot 
xpoints =df["Weather Condition"].head(50)
ypoints =df["Temp_C"].head(50)


plt.plot(xpoints, ypoints)
#plt.show()

# %%
#Plotting Without Line (represt markers)

xpoints =df["Weather Condition"].head(30)
ypoints =df["Temp_C"].head(30)


plt.plot(xpoints, ypoints,'o') 
# instead of 'o', use many marker reference like * ,'.' ,'X' many more

# %%
# labelling of graph

xpoints =df["Weather Condition"].head(30)
ypoints =df["Temp_C"].head(30)


plt.plot(xpoints, ypoints) 
plt.xlabel("Weather Condition")
plt.ylabel("Temperature")
plt.title("Graph Using Matplotlib")
# Out:
# Text(0.5, 1.0, 'Graph Using Matplotlib')

# %%
# can Use font and colour also

xpoints =df["Weather Condition"].head(30)
ypoints =df["Temp_C"].head(30)


plt.plot(xpoints, ypoints,'o') 
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title( "Graph Using Matplotlib",fontdict = font1)
plt.xlabel("Weather Condition", fontdict = font2)
plt.ylabel("Temperature", fontdict = font2)
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# to show grid use 
plt.grid()

# %% [markdown]
# # -------------> END <----------
