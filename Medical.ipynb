# %% [markdown]
# # Medical Premium

# %%
import pandas as pd

# %%
df=pd.read_csv("Medicalpremium.csv")
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
len(df)
# Out:
# 986

# %%
df.shape
# Out:
# (986, 11)

# %%
df.keys()
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age    Diabetes  BloodPressureProblems  AnyTransplants  \
# count  986.000000  986.000000             986.000000      986.000000
# mean    41.745436    0.419878               0.468560        0.055781
# std     13.963371    0.493789               0.499264        0.229615
# min     18.000000    0.000000               0.000000        0.000000
# 25%     30.000000    0.000000               0.000000        0.000000
# 50%     42.000000    0.000000               0.000000        0.000000
# 75%     53.000000    1.000000               1.000000        0.000000
# max     66.000000    1.000000               1.000000        1.000000
#
#        AnyChronicDiseases      Height      Weight  KnownAllergies  \
# count          986.000000  986.000000  986.000000      986.000000
# mean             0.180527  168.182556   76.950304        0.215010
# std              0.384821   10.098155   14.265096        0.411038
# min              0.000000  145.000000   51.000000        0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
# Age                        986 non-null int64
# Diabetes                   986 non-null int64
# BloodPressureProblems      986 non-null int64
# AnyTransplants             986 non-null int64
# AnyChronicDiseases         986 non-null int64
# Height                     986 non-null int64
# Weight                     986 non-null int64
# KnownAllergies             986 non-null int64
# HistoryOfCancerInFamily    986 non-null int64
# NumberOfMajorSurgeries     986 non-null int64
# PremiumPrice               986 non-null int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
df["PremiumPrice"].unique()
# Out:
# array([25000, 29000, 23000, 28000, 21000, 15000, 35000, 30000, 32000,
#        19000, 24000, 38000, 31000, 26000, 39000, 22000, 40000, 18000,
#        34000, 20000, 16000, 36000, 27000, 17000], dtype=int64)

# %%
df[(df["PremiumPrice"]>=20000) & (df["Diabetes"]>0) & ( df["BloodPressureProblems"]>0)  ]
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 29    33         1                      1               0                   1
# 41    66         1                      1               0                   0
# 46    25         1                      1               0                   0
# ..   ...       ...                    ...             ...                 ...
# 965   35         1                      1               0                   0
# 967   42         1                      1               0                   0
# 970   46         1                      1               0                   0
# 982   64         1                      1               0                   0
# 984   47         1                      1               0                   0
#
# ...

# %%
# Group Diabetic Patient's age wise

df.groupby(["Age"])["Diabetes"].sum()
# Out:
# Age
# 18     4
# 19     6
# 20     6
# 21     5
# 22     5
# 23     1
# 24    13
# 25     9
# 26     5
# 27    10
# 28     7
# 29     7
# 30     7
# 31     5
# 32     4
# 33     6
# 34     4
# 35    11
# 36    10
# 37     6
# 38     4
# 39     4
# 40     5
# 41    10
# 42    12
# 43    10
# 44     8
# 45    11
# 46    13
# 47    11
# 48    11
# 49    12
# 50     9
# 51     7
# 52    11
# 53     8
# 54    10
# 55     8
# 56     8
# 57     8
# 58    11
# 59    14
# 60     6
# 61     8
# 62    10
# 63    10
# 64    15
# 65    12
# 66    17
# Name: Diabetes, dtype: int64

# %%
df["TotalDisease"]=df["Diabetes"]+df["BloodPressureProblems"]+df["AnyTransplants"]+df["AnyChronicDiseases"]
df
# Out:
#      Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0     45         0                      0               0                   0
# 1     60         1                      0               0                   0
# 2     36         1                      1               0                   0
# 3     52         1                      1               0                   1
# 4     38         0                      0               0                   1
# ..   ...       ...                    ...             ...                 ...
# 981   18         0                      0               0                   0
# 982   64         1                      1               0                   0
# 983   56         0                      1               0                   0
# 984   47         1                      1               0                   0
# 985   21         0                      0               0                   0
#
# ...

# %%
# Make new dataframe containing total disease,height, weight,price with age 

new_df= df.loc[:,["Age","TotalDisease","Height","Weight","PremiumPrice"]]
new_df.set_index("Age")
# Out:
#      TotalDisease  Height  Weight  PremiumPrice
# Age
# 45              0     155      57         25000
# 60              1     180      73         29000
# 36              2     158      59         23000
# 52              3     183      93         28000
# 38              1     166      88         23000
# ..            ...     ...     ...           ...
# 18              0     169      67         15000
# 64              2     153      70         28000
# 56              1     155      71         29000
# 47              2     158      73         39000
# 21              0     158      75         15000
#
# [986 rows x 4 columns]

# %%
new_df.plot(x="Age", y="PremiumPrice")

# %%
# use matplotlib

import matplotlib.pyplot as plt

# %%
# show pie chart for Age vs Total disease

xlabel=df["Age"]
ylabel=df["TotalDisease"]

plt.pie(xlabel,ylabel)
plt.show()

# %%
#Grid Plotting 

xlabel=df["Age"].head(20)
ylabel=df["TotalDisease"].head(20)
plt.plot(xlabel, ylabel,color='black')
plt.grid(color = 'black')
font1 = {'family':'serif','color':'blue','size':20}
plt.title("Age vs Total Disease" ,fontdict = font1)
plt.xlabel("Age")
plt.ylabel("Total Disease")
plt.show()

# %%
# import seaborn library for styling
import seaborn as sb

## Target Variable 
sb.kdeplot(df.PremiumPrice)

# %%
# print unique value in each column

for i in df.columns:
    print(i, len(df[i].unique()))
# Out:
# Age 49
# Diabetes 2
# BloodPressureProblems 2
# AnyTransplants 2
# AnyChronicDiseases 2
# Height 44
# Weight 74
# KnownAllergies 2
# HistoryOfCancerInFamily 2
# NumberOfMajorSurgeries 4
# PremiumPrice 24
# TotalDisease 5

# %%
binary_feature = [i for i in df.columns if (len(df[i].unique()) == 2)]
target_feature = 'PremiumPrice'
disceate_feature = [i for i in df.columns if (i not in binary_feature) and (i not in target_feature)]

# %%
fig, ax = plt.subplots(5,2, figsize = (20,30))
sb.countplot(ax =ax[0,0], data = df , x = binary_feature[0])
sb.barplot(ax =ax[0,1], data = df , x = binary_feature[0], y = target_feature)
sb.countplot(ax =ax[1,0], data = df , x = binary_feature[1])
sb.barplot(ax =ax[1,1], data = df , x = binary_feature[1], y = target_feature)
sb.countplot(ax =ax[2,0], data = df , x = binary_feature[2])
sb.barplot(ax =ax[2,1], data = df , x = binary_feature[2], y = target_feature)
sb.countplot(ax =ax[3,0], data = df , x = binary_feature[3])
sb.barplot(ax =ax[3,1], data = df , x = binary_feature[3], y = target_feature)
sb.countplot(ax =ax[4,0], data = df , x = binary_feature[4])
sb.barplot(ax =ax[4,1], data = df , x = binary_feature[4], y = target_feature)
# sb.countplot(ax =ax[5,0], data = df , x = binary_feature[5])//
# sb.barplot(ax =ax[5,1], data = df , x = binary_feature[5], y = target_feature)

# %% [markdown]
# Based on visualzation following point may be colcluded.
#
# If you have a disease the premium price is higher than others
# count of Blood pressure & diabities patient is higher than other list of disease

# %%
plt.figure(figsize =(18,10))
sb.heatmap(df.corr(), annot =True)

# %%
# Premium Price
plt.figure(figsize=(10, 6))
plt.xticks(rotation=70)
sb.countplot(x='PremiumPrice', data=df)

# %%
# age
plt.figure(figsize=(10, 6))
sb.histplot(x='Age', data=df, bins=20, kde=True, color='green')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-817918f846c4> in <module>
#       1 # age
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sb.histplot(x='Age', data=df, bins=20, kde=True, color='green')
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
# Height
plt.figure(figsize=(10, 6))
sb.histplot(x='Height', data=df, bins=20, kde=True, color='red')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-a5062d0de8c2> in <module>
#       1 # Height
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sb.histplot(x='Height', data=df, bins=20, kde=True, color='red')
#
# AttributeError: module 'seaborn' has no attribute 'histplot'
